# %%
import pymysql

# MySQL 연결
conn = pymysql.connect(host='localhost', user='root', password="1234", charset='utf8')

# MySQL DB 생성
with conn:
  with conn.cursor() as cur:
        cur.execute('CREATE DATABASE stockdb')
        conn.commit()

# %%
import pandas as pd

# 주식 데이터 읽어들이기 
df = pd.read_csv('003490.KS.csv')

df
# Out:
#             Date          Open          High           Low         Close  \
# 0     2012-01-02  43669.421875  44318.226563  43170.343750  43419.882813
# 1     2012-01-03  43819.148438  44817.304688  43819.148438  44617.675781
# 2     2012-01-04  44917.121094  44917.121094  43968.871094  44318.226563
# 3     2012-01-05  44318.226563  44517.859375  43220.253906  43918.964844
# 4     2012-01-06  43469.792969  44018.777344  42621.355469  43070.527344
# ...          ...           ...           ...           ...           ...
# 2622  2022-08-30  25600.000000  26150.000000  25550.000000  26100.000000
# 2623  2022-08-31  25950.000000  26850.000000  25850.000000  26850.000000
# 2624  2022-09-01  26700.000000  27050.000000  26150.000000  26150.000000
# 2625  2022-09-02  26400.000000  26550.000000  25950.000000  26150.000000
# 2626  2022-09-05  26050.000000  26100.000000  25550.000000  25650.000000
#
#          Adj Close   Volume
# 0     42977.582031   333348
# 1     44163.171875   573328
# ...

# %%
df['1day'] = df.Close.diff(-1).multiply(-1)

df
# Out:
#             Date          Open          High           Low         Close  \
# 0     2012-01-02  43669.421875  44318.226563  43170.343750  43419.882813
# 1     2012-01-03  43819.148438  44817.304688  43819.148438  44617.675781
# 2     2012-01-04  44917.121094  44917.121094  43968.871094  44318.226563
# 3     2012-01-05  44318.226563  44517.859375  43220.253906  43918.964844
# 4     2012-01-06  43469.792969  44018.777344  42621.355469  43070.527344
# ...          ...           ...           ...           ...           ...
# 2622  2022-08-30  25600.000000  26150.000000  25550.000000  26100.000000
# 2623  2022-08-31  25950.000000  26850.000000  25850.000000  26850.000000
# 2624  2022-09-01  26700.000000  27050.000000  26150.000000  26150.000000
# 2625  2022-09-02  26400.000000  26550.000000  25950.000000  26150.000000
# 2626  2022-09-05  26050.000000  26100.000000  25550.000000  25650.000000
#
#          Adj Close   Volume         1day
# 0     42977.582031   333348  1197.792968
# ...

# %%
df['2day'] = df.Close.diff(-2).multiply(-1)
df
# Out:
#             Date          Open          High           Low         Close  \
# 0     2012-01-02  43669.421875  44318.226563  43170.343750  43419.882813
# 1     2012-01-03  43819.148438  44817.304688  43819.148438  44617.675781
# 2     2012-01-04  44917.121094  44917.121094  43968.871094  44318.226563
# 3     2012-01-05  44318.226563  44517.859375  43220.253906  43918.964844
# 4     2012-01-06  43469.792969  44018.777344  42621.355469  43070.527344
# ...          ...           ...           ...           ...           ...
# 2622  2022-08-30  25600.000000  26150.000000  25550.000000  26100.000000
# 2623  2022-08-31  25950.000000  26850.000000  25850.000000  26850.000000
# 2624  2022-09-01  26700.000000  27050.000000  26150.000000  26150.000000
# 2625  2022-09-02  26400.000000  26550.000000  25950.000000  26150.000000
# 2626  2022-09-05  26050.000000  26100.000000  25550.000000  25650.000000
#
#          Adj Close   Volume         1day         2day
# ...

# %%
df['3day'] = df.Close.diff(-3).multiply(-1)
df
# Out:
#             Date          Open          High           Low         Close  \
# 0     2012-01-02  43669.421875  44318.226563  43170.343750  43419.882813
# 1     2012-01-03  43819.148438  44817.304688  43819.148438  44617.675781
# 2     2012-01-04  44917.121094  44917.121094  43968.871094  44318.226563
# 3     2012-01-05  44318.226563  44517.859375  43220.253906  43918.964844
# 4     2012-01-06  43469.792969  44018.777344  42621.355469  43070.527344
# ...          ...           ...           ...           ...           ...
# 2622  2022-08-30  25600.000000  26150.000000  25550.000000  26100.000000
# 2623  2022-08-31  25950.000000  26850.000000  25850.000000  26850.000000
# 2624  2022-09-01  26700.000000  27050.000000  26150.000000  26150.000000
# 2625  2022-09-02  26400.000000  26550.000000  25950.000000  26150.000000
# 2626  2022-09-05  26050.000000  26100.000000  25550.000000  25650.000000
#
#          Adj Close   Volume         1day         2day         3day
# ...

# %%
df['4day'] = df.Close.diff(-4).multiply(-1)
df
# Out:
#             Date          Open          High           Low         Close  \
# 0     2012-01-02  43669.421875  44318.226563  43170.343750  43419.882813
# 1     2012-01-03  43819.148438  44817.304688  43819.148438  44617.675781
# 2     2012-01-04  44917.121094  44917.121094  43968.871094  44318.226563
# 3     2012-01-05  44318.226563  44517.859375  43220.253906  43918.964844
# 4     2012-01-06  43469.792969  44018.777344  42621.355469  43070.527344
# ...          ...           ...           ...           ...           ...
# 2622  2022-08-30  25600.000000  26150.000000  25550.000000  26100.000000
# 2623  2022-08-31  25950.000000  26850.000000  25850.000000  26850.000000
# 2624  2022-09-01  26700.000000  27050.000000  26150.000000  26150.000000
# 2625  2022-09-02  26400.000000  26550.000000  25950.000000  26150.000000
# 2626  2022-09-05  26050.000000  26100.000000  25550.000000  25650.000000
#
#          Adj Close   Volume         1day         2day         3day  \
# ...

# %%
df['5day'] = df.Close.diff(-5).multiply(-1)
df
# Out:
#             Date          Open          High           Low         Close  \
# 0     2012-01-02  43669.421875  44318.226563  43170.343750  43419.882813
# 1     2012-01-03  43819.148438  44817.304688  43819.148438  44617.675781
# 2     2012-01-04  44917.121094  44917.121094  43968.871094  44318.226563
# 3     2012-01-05  44318.226563  44517.859375  43220.253906  43918.964844
# 4     2012-01-06  43469.792969  44018.777344  42621.355469  43070.527344
# ...          ...           ...           ...           ...           ...
# 2622  2022-08-30  25600.000000  26150.000000  25550.000000  26100.000000
# 2623  2022-08-31  25950.000000  26850.000000  25850.000000  26850.000000
# 2624  2022-09-01  26700.000000  27050.000000  26150.000000  26150.000000
# 2625  2022-09-02  26400.000000  26550.000000  25950.000000  26150.000000
# 2626  2022-09-05  26050.000000  26100.000000  25550.000000  25650.000000
#
#          Adj Close   Volume         1day         2day         3day  \
# ...

# %%
df['6day'] = df.Close.diff(-6).multiply(-1)
df
# Out:
#             Date          Open          High           Low         Close  \
# 0     2012-01-02  43669.421875  44318.226563  43170.343750  43419.882813
# 1     2012-01-03  43819.148438  44817.304688  43819.148438  44617.675781
# 2     2012-01-04  44917.121094  44917.121094  43968.871094  44318.226563
# 3     2012-01-05  44318.226563  44517.859375  43220.253906  43918.964844
# 4     2012-01-06  43469.792969  44018.777344  42621.355469  43070.527344
# ...          ...           ...           ...           ...           ...
# 2622  2022-08-30  25600.000000  26150.000000  25550.000000  26100.000000
# 2623  2022-08-31  25950.000000  26850.000000  25850.000000  26850.000000
# 2624  2022-09-01  26700.000000  27050.000000  26150.000000  26150.000000
# 2625  2022-09-02  26400.000000  26550.000000  25950.000000  26150.000000
# 2626  2022-09-05  26050.000000  26100.000000  25550.000000  25650.000000
#
#          Adj Close   Volume         1day         2day         3day  \
# ...

# %%
df['7day'] = df.Close.diff(-7).multiply(-1)
df
# Out:
#             Date          Open          High           Low         Close  \
# 0     2012-01-02  43669.421875  44318.226563  43170.343750  43419.882813
# 1     2012-01-03  43819.148438  44817.304688  43819.148438  44617.675781
# 2     2012-01-04  44917.121094  44917.121094  43968.871094  44318.226563
# 3     2012-01-05  44318.226563  44517.859375  43220.253906  43918.964844
# 4     2012-01-06  43469.792969  44018.777344  42621.355469  43070.527344
# ...          ...           ...           ...           ...           ...
# 2622  2022-08-30  25600.000000  26150.000000  25550.000000  26100.000000
# 2623  2022-08-31  25950.000000  26850.000000  25850.000000  26850.000000
# 2624  2022-09-01  26700.000000  27050.000000  26150.000000  26150.000000
# 2625  2022-09-02  26400.000000  26550.000000  25950.000000  26150.000000
# 2626  2022-09-05  26050.000000  26100.000000  25550.000000  25650.000000
#
#          Adj Close   Volume         1day         2day         3day  \
# ...

# %%
df['14day'] = df.Close.diff(-14).multiply(-1)
df
# Out:
#             Date          Open          High           Low         Close  \
# 0     2012-01-02  43669.421875  44318.226563  43170.343750  43419.882813
# 1     2012-01-03  43819.148438  44817.304688  43819.148438  44617.675781
# 2     2012-01-04  44917.121094  44917.121094  43968.871094  44318.226563
# 3     2012-01-05  44318.226563  44517.859375  43220.253906  43918.964844
# 4     2012-01-06  43469.792969  44018.777344  42621.355469  43070.527344
# ...          ...           ...           ...           ...           ...
# 2622  2022-08-30  25600.000000  26150.000000  25550.000000  26100.000000
# 2623  2022-08-31  25950.000000  26850.000000  25850.000000  26850.000000
# 2624  2022-09-01  26700.000000  27050.000000  26150.000000  26150.000000
# 2625  2022-09-02  26400.000000  26550.000000  25950.000000  26150.000000
# 2626  2022-09-05  26050.000000  26100.000000  25550.000000  25650.000000
#
#          Adj Close   Volume         1day         2day         3day  \
# ...

# %%
# NA 있는 행 제거 
df.dropna(inplace=True)
df
# Out:
#             Date          Open          High           Low         Close  \
# 0     2012-01-02  43669.421875  44318.226563  43170.343750  43419.882813
# 1     2012-01-03  43819.148438  44817.304688  43819.148438  44617.675781
# 2     2012-01-04  44917.121094  44917.121094  43968.871094  44318.226563
# 3     2012-01-05  44318.226563  44517.859375  43220.253906  43918.964844
# 4     2012-01-06  43469.792969  44018.777344  42621.355469  43070.527344
# ...          ...           ...           ...           ...           ...
# 2608  2022-08-09  25850.000000  26000.000000  25650.000000  25900.000000
# 2609  2022-08-10  25850.000000  25950.000000  25450.000000  25550.000000
# 2610  2022-08-11  25900.000000  25950.000000  25750.000000  25950.000000
# 2611  2022-08-12  26050.000000  26200.000000  25850.000000  26200.000000
# 2612  2022-08-16  26450.000000  27050.000000  26250.000000  26600.000000
#
#          Adj Close   Volume         1day         2day         3day  \
# ...

# %%
pip install pymysql

# %%
pip install sqlalchemy

# %%
from sqlalchemy import create_engine
import pymysql

db_config = 'mysql+pymysql://root:1234@localhost:3306/stockdb'
conn = create_engine(db_config).connect()

# %%
df.to_sql(name='koreanair20122017', con=conn, if_exists='fail', index=False)
# Out:
# 2613
